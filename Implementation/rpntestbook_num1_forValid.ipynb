# %%
# %matplotlib inline

import pickle
import pdb
import numpy as np

with open('vdump.pkl', 'rb') as file:
    xt, yt, tpreds, train_selection_tensor, gtt, reg_loss_list, cls_loss_list, oal_loss_list = pickle.load(file)

# %%
# # plot cost development
import matplotlib.pyplot as plt
plt.figure()
plt.plot(reg_loss_list, label='reg loss', c='steelblue')
plt.plot(cls_loss_list, label='cls loss', c='darkblue')
plt.plot(oal_loss_list, label='overall loss', c='blue')
plt.legend()
plt.show()

ROW = 6
COL = 10
CLOAK_DS = 1
T = 1

img = xt# if CLOAK_DS == 0  else xv[-1]
label = yt# if CLOAK_DS == 0  else yv[-1]
pdics = tpreds# if CLOAK_DS == 0 else vpreds[-1]
sctio = train_selection_tensor# if CLOAK_DS == 0 else vslt[-1]

pdb.set_trace()
plt.imshow(img[:,:,:]); plt.show()
print(label)
for t in range(4):
    print('ground truth tensor',t,':', gtt[0, ROW, COL, T+t*9])
print('mean predictions:')
# shape: (1, 16, 16, 36)
#for i in range(9):
#print('0:')
print('x:',np.mean(pdics[ROW, COL,  [np.arange(0,9)]]))
#pdb.set_trace()
#print('x:',vpreds[0, ROW, 2,  0])
#print('x:',vpreds[0, ROW, 2,  9])
#print('x:',p10, 2,0, ROW, 2,  18])
#print('x:',vpreds[0, ROW, 2,  27])
print('y:',np.mean(pdics[ROW, COL,  [np.arange(0,9)+9]]))
print('w:',np.mean(pdics[ROW, COL, [np.arange(0,9)+18]]))
print('h:',np.mean(pdics[ROW, COL, [np.arange(0,9)+27]]))
#print('2:')
#print('x:',np.mean(vpreds[0, , ROW,  [np.arange(0,9)]]))
#print('y:',np.mean(vpreds[0, COL, ROW,  [np.arange(0,9)+9]]))
#print('w:',np.mean(vpreds[0, COL, ROW, [np.arange(0,9)+18]]))
#print('h:',np.mean(vpreds[0, COL, ROW, [np.arange(0,9)+27]]))
#print('x:',np.mean(vpreds[0, 5, 9,  [np.arange(0,9)]]))
#print('y:',np.mean(vpreds[0, 5, 9,  [np.arange(0,9)+9]]))
#print('w:',np.mean(vpreds[0, 5, 9, [np.arange(0,9)+18]]))
#print('h:',np.mean(vpreds[0, 5, 9, [np.arange(0,9)+27]]))
#print('x:',preds[0, 2, ROW,  0])
#print('y:',np.mean(vpreds[0, 2, ROW,  9]))
#print('w:',np.mean(vpreds[0, 2, ROW, 18]))
#print('h:',np.mean(vpreds[0, 2, ROW, 27]))

#print('ground truth tensor tensor:')
# gtt shape: (1, 16, 16, 36)

for t in range(9):
    print('selection tensor',t,':', sctio[0, :, :, t, 1])

#print('y:', slt[i, 0, :, :, ])
#print('w:', slt[i, 0, :, :,18])
#print('h:', slt[i, 0, :, :,27])
# slt shape: (1, 16, 16, 9, 3)
# Out:
# --Return--
# > <ipython-input-2-61de87ae23b1>(20)<module>()->None
# -> pdb.set_trace()
# (Pdb) c
# [[5, 191, 212, 56, 56, 0.0, 2.0], [4, 42, 138, 56, 56, 0.0, 2.0], [3, 58, 71, 56, 56, 0.0, 2.0], [-9, -9, -9, -9, -9, -9, -9], [-9, -9, -9, -9, -9, -9, -9]]
# ground truth tensor 0 : -2.0
# ground truth tensor 1 : -2.0
# ground truth tensor 2 : -2.0
# ground truth tensor 3 : -2.0
# mean predictions:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-61de87ae23b1> in <module>()
#      27 #for i in range(9):
#      28 #print('0:')
# ---> 29 print('x:',np.mean(pdics[ROW, COL,  [np.arange(0,9)]]))
#      30 #pdb.set_trace()
#      31 #print('x:',vpreds[0, ROW, 2,  0])
#
# IndexError: index 6 is out of bounds for axis 0 with size 1

# %%
import matplotlib.pyplot as plt
plt.imshow(img.reshape((256,256,3)))
plt.show()
for T in range(9):
    print('\nanchor slice',T,'\n')
    #import pdb; pdb.set_trace()
    xs = np.where(sctio[0,:, :, T ] >= 1)[0].tolist()
    ys = np.where(sctio[0,:, :, T ] >= 1)[1].tolist()
    #pdb.set_trace()
    for i in range(len(xs)):
        print('\nxs:',xs[i],'ys:',ys[i])
        print('mnist number:', sctio[0,xs[i],ys[i],T])
        print('x box:',gtt[0,xs[i],ys[i],T+0],
              'y box:',gtt[0,xs[i], ys[i], T+9],
              'w box:', gtt[0,xs[i], ys[i], T+18],
              'h box:', gtt[0,xs[i], ys[i], T+27])
        #pdb.set_trace()
        print('x anc:', tpreds[0,xs[i], ys[i], T+0],
              'y anc:', tpreds[0,xs[i], ys[i], T+9],
              'w anc:', tpreds[0,xs[i], ys[i], T+18],
              'h anc:', tpreds[0,xs[i], ys[i], T+27])
        #print(tpreds[0,:,:,0])
    #print('iteration:', iter, 'reg loss:', lr_, 'cls loss:', lc_, 'overall loss:', ol_)
    #iter += 1
# Out:
# anchor slice 0
#
#
# xs: 2 ys: 8
# mnist number: 42.0
# x box: 42.0 y box: 138.0 w box: 56.0 h box: 56.0
# x anc: 79.42256 y anc: 177.77286 w anc: 260.94778 h anc: 82.89662
#
# xs: 3 ys: 4
# mnist number: 58.0
# x box: 58.0 y box: 71.0 w box: 56.0 h box: 56.0
# x anc: 172.87457 y anc: 168.15277 w anc: 170.84442 h anc: 64.13652
#
# xs: 11 ys: 13
# mnist number: 191.0
# x box: 191.0 y box: 212.0 w box: 56.0 h box: 56.0
# x anc: 118.3771 y anc: 211.09229 w anc: 312.78024 h anc: 66.89328
#
# anchor slice 1
#
#
# xs: 2 ys: 8
# mnist number: 42.0
# x box: 42.0 y box: 138.0 w box: 56.0 h box: 56.0
# x anc: 51.079853 y anc: 185.9331 w anc: 40.637672 h anc: 46.069946
#
# xs: 3 ys: 4
# mnist number: 58.0
# x box: 58.0 y box: 71.0 w box: 56.0 h box: 56.0
# x anc: 191.69261 y anc: 175.65659 w anc: 70.73159 h anc: 58.007706
#
# anchor slice 2
#
#
# xs: 2 ys: 8
# mnist number: 42.0
# x box: 42.0 y box: 138.0 w box: 56.0 h box: 56.0
# x anc: 46.110355 y anc: 176.7404 w anc: 81.457825 h anc: 53.494972
#
# xs: 3 ys: 4
# mnist number: 58.0
# x box: 58.0 y box: 71.0 w box: 56.0 h box: 56.0
# x anc: 179.30447 y anc: 163.62097 w anc: 81.272995 h anc: 83.708824
#
# anchor slice 3
#
#
# xs: 2 ys: 8
# mnist number: 42.0
# x box: 42.0 y box: 138.0 w box: 56.0 h box: 56.0
# x anc: 65.66365 y anc: 169.145 w anc: 73.02612 h anc: 453.66187
#
# xs: 3 ys: 4
# mnist number: 58.0
# x box: 58.0 y box: 71.0 w box: 56.0 h box: 56.0
# x anc: 195.11005 y anc: 173.7155 w anc: 90.99878 h anc: 482.58002
#
# anchor slice 4
#
#
# xs: 2 ys: 8
# mnist number: 42.0
# x box: 42.0 y box: 138.0 w box: 56.0 h box: 56.0
# x anc: 72.32474 y anc: 179.43164 w anc: 155.8557 h anc: 181.97382
#
# xs: 3 ys: 4
# mnist number: 58.0
# x box: 58.0 y box: 71.0 w box: 56.0 h box: 56.0
# x anc: 166.7612 y anc: 177.17036 w anc: 181.33675 h anc: 206.6333
#
# anchor slice 5
#
#
# xs: 2 ys: 8
# mnist number: 42.0
# x box: 42.0 y box: 138.0 w box: 56.0 h box: 56.0
# x anc: 75.506485 y anc: 187.58418 w anc: 58.792038 h anc: 82.09109
#
# xs: 3 ys: 4
# mnist number: 58.0
# x box: 58.0 y box: 71.0 w box: 56.0 h box: 56.0
# x anc: 191.12221 y anc: 187.9933 w anc: 56.644943 h anc: 65.6155
#
# anchor slice 6
#
#
# xs: 2 ys: 8
# mnist number: 42.0
# x box: 42.0 y box: 138.0 w box: 56.0 h box: 56.0
# x anc: 73.55148 y anc: 183.58958 w anc: 63.745235 h anc: 49.162296
#
# xs: 3 ys: 4
# mnist number: 58.0
# x box: 58.0 y box: 71.0 w box: 56.0 h box: 56.0
# x anc: 169.69437 y anc: 189.2475 w anc: 56.546425 h anc: 74.17314
#
# anchor slice 7
#
#
# xs: 2 ys: 8
# mnist number: 42.0
# x box: 42.0 y box: 138.0 w box: 56.0 h box: 56.0
# x anc: 66.6689 y anc: 186.58257 w anc: 64.98196 h anc: 41.464417
#
# xs: 3 ys: 4
# mnist number: 58.0
# x box: 58.0 y box: 71.0 w box: 56.0 h box: 56.0
# x anc: 191.45326 y anc: 163.26126 w anc: 96.46083 h anc: 84.323494
#
# anchor slice 8
#
#
# xs: 2 ys: 8
# mnist number: 42.0
# x box: 42.0 y box: 138.0 w box: 56.0 h box: 56.0
# x anc: 70.96531 y anc: 171.23503 w anc: 64.302536 h anc: 54.220814
#
# xs: 3 ys: 4
# mnist number: 58.0
# x box: 58.0 y box: 71.0 w box: 56.0 h box: 56.0
# x anc: 167.93198 y anc: 165.79536 w anc: 77.28641 h anc: 68.53487
